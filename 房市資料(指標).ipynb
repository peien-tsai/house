# %%
import pandas as pd
import numpy as np
import json

# %%
# 讀取房市資料
quotes = pd.read_csv('C:/Users/Big data/Desktop/output/output.csv', header=0)

# %%
quotes
# Out:
#                     houseid district transaction_object  \
# 1       RPOPMLOJKHIFFHF87CA      中和區          房地(土地+建物)
# 2       RPROMLMLQHHFFCF28EA      新店區          房地(土地+建物)
# 3       RPQNMLRLQHHFFHF88CA      中和區          房地(土地+建物)
# 4       RPQNMLRJQHHFFDF28CA      汐止區                 車位
# 5       RPWQMLRLRHHFFEF96CA      八里區          房地(土地+建物)
# ...                     ...      ...                ...
# 366840  RPXNMLTLJIOFFIF37CA      鶯歌區          房地(土地+建物)
# 366841  RPPPMLPLJIOFFIF98CA      鶯歌區          房地(土地+建物)
# 366842  RPWRMLLKJIOFFIF76CA      樹林區          房地(土地+建物)
# 366843  RPQPMLMKJIOFFIF68CA      鶯歌區       房地(土地+建物)+車位
# 366844  RPPOMLOKJIOFFIF68CA      樹林區          房地(土地+建物)
#
#                       address landuse floor total_floor     buildingsate  \
# 1           新北市中和區中安街40巷1~30號       住    六層         十二層  住宅大樓(11層含以上有電梯)
# 2           新北市新店區玫瑰路58巷1~30號       住    四層          五層     公寓(5樓含以下無電梯)
# 3       新北市中和區員山路423巷14弄1~30號       住    三層          五層     公寓(5樓含以下無電梯)
# 4         新北市汐止區大同路二段211~240號       住   NaN         NaN               其他
# 5        新北市八里區中山路二段406巷1~30號       住    六層          八層    華廈(10層含以下有電梯)
# ...                       ...     ...   ...         ...              ...
# 366840        新北市鶯歌區高職西街1~30號       住    五層          五層     公寓(5樓含以下無電梯)
# 366841        新北市鶯歌區福德一路1~30號       住    三層          五層     公寓(5樓含以下無電梯)
# 366842      新北市樹林區千歲街31巷1~30號       住    四層          五層     公寓(5樓含以下無電梯)
# 366843       新北市鶯歌區高職西街31~60號       住    五層          八層    華廈(10層含以下有電梯)
# 366844      新北市樹林區八德街121~150號       住    四層          四層     公寓(5樓含以下無電梯)
#
#         mainuse material  ...  ting  uei  manage  totalprice  trade_date  \
# 1           住家用   鋼筋混凝土造  ...     1    2       1    13900000  2012-05-18
# 2           住家用   鋼筋混凝土造  ...     2    2       1     5000000  2012-07-11
# 3           住家用   鋼筋混凝土造  ...     1    1       0     4500000  2012-07-08
# 4           NaN      NaN  ...     0    0       1     1650000  2012-07-02
# 5           住家用   鋼筋混凝土造  ...     1    1       0     5350000  2012-07-08
# ...         ...      ...  ...   ...  ...     ...         ...         ...
# 366840      住家用   鋼筋混凝土造  ...     2    2       0     3300000  2019-10-15
# 366841      住家用   鋼筋混凝土造  ...     2    1       0     4480000  2019-10-09
# 366842      住家用   鋼筋混凝土造  ...     1    1       0     4600000  2019-10-11
# 366843  見其他登記事項   鋼筋混凝土造  ...     2    2       1     7950000  2019-10-29
# 366844      住家用   鋼筋混凝土造  ...     2    1       0     5600000  2019-10-10
#
#         build_date garage_type garage_area garage_price  pricepermeter
# 1       1997-05-02         NaN        0.00          0.0         155047
# 2       1985-10-14         NaN        0.00          0.0          48445
# 3       1983-02-26         NaN        0.00          0.0          78125
# 4              NaN          其他       19.76    1650000.0              0
# 5       2009-02-19         NaN        0.00          0.0          44517
# ...            ...         ...         ...          ...            ...
# 366840  1995-11-21         NaN        0.00          0.0          32104
# 366841         NaN         NaN        0.00          0.0          45528
# 366842  1983-09-26         NaN        0.00          0.0          66734
# 366843  2019-01-03        坡道平面       24.10          0.0          50965
# 366844  1982-02-26         NaN        0.00          0.0          70193
#
# [366844 rows x 22 columns]

# %%
q = quotes.groupby(['trade_date'],as_index=False)['trade_date'].agg({'cnt':'count'})
